# %%
import matplotlib.pyplot as plt
y = []

for x in range((-2),3):
    a = ((x**2)-1)
    y.append(a)

plt.plot(y)

# %%
import matplotlib.pyplot as plt

y = []

for x in range(0,11):
    a = ((x**2)-1)
    y.append(a)
plt.plot(y)
